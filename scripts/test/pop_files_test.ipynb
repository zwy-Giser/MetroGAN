# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img=Image.open(r"C:\research\city_architecture\data\processed data\LandScan Global 2015_processed\10808-China-Shandong-Yantai.png").convert('F')
img_arr=np.array(img)
img_arr=img_arr/img_arr.max()
plt.hist(img_arr.flatten(),bins=100)
plt.show()
plt.close()

# %%
plt.imshow(img_arr)
plt.show()
